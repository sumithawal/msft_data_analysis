# %%
#references 
#  https://www.kaggle.com/yashvi/window-store-analysis

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7620e66b-cb62-4309-86f6-5c4b17ae5032" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7620e66b-cb62-4309-86f6-5c4b17ae5032">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving msft.csv to msft.csv

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import tensorflow as tf 
import io
from matplotlib import style 
style.use('ggplot')

# %%
df = pd.read_csv(io.BytesIO(uploaded['msft.csv']))

# %%
df.head()
# Out:
#                                                 Name  Rating  ...        Date Price
# 0                                     Dynamic Reader     3.5  ...  07-01-2014  Free
# 1  Chemistry, Organic Chemistry and Biochemistry-...     3.0  ...  08-01-2014  Free
# 2                                         BookViewer     3.5  ...  29-02-2016  Free
# 3                                 Brick Instructions     3.5  ...  30-01-2018  Free
# 4  Introduction to Python Programming by GoLearni...     2.0  ...  30-01-2018  Free
#
# [5 rows x 6 columns]

# %%
df.index = df.Date
df.head()
# Out:
#                                                          Name  ...  Price
# Date                                                           ...
# 07-01-2014                                     Dynamic Reader  ...   Free
# 08-01-2014  Chemistry, Organic Chemistry and Biochemistry-...  ...   Free
# 29-02-2016                                         BookViewer  ...   Free
# 30-01-2018                                 Brick Instructions  ...   Free
# 30-01-2018  Introduction to Python Programming by GoLearni...  ...   Free
#
# [5 rows x 6 columns]

# %%
# As most of the values are Free in the price column we need to set it to zero 
for i in range(len(df)):
    if df.Price[i]=='Free':
        df.Price[i]=0.0
df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#                                                          Name  ...  Price
# Date                                                           ...
# 07-01-2014                                     Dynamic Reader  ...      0
# 08-01-2014  Chemistry, Organic Chemistry and Biochemistry-...  ...      0
# 29-02-2016                                         BookViewer  ...      0
# 30-01-2018                                 Brick Instructions  ...      0
# 30-01-2018  Introduction to Python Programming by GoLearni...  ...      0
#
# [5 rows x 6 columns]

# %%
category_array = df.Category.unique()
mean_rating_list =[]
for i in range(len(category_array)):
    df1 =  df[df['Category']==category_array[i]]
    mean_rating = df1['Rating'].mean()
    mean_rating_list.append(mean_rating)
# mean_rating_list

index =[ x for x in range(len(category_array))]

plt.bar(index,mean_rating_list)
plt.xticks(index,category_array,rotation=90)
plt.xlabel("Category_of_Books")
plt.ylabel("Average_Rating")
plt.plot()
# Out:
# []

# %%
#calulating which category of books whom were rated the most =
category_array = df.Category.unique()
no_of_rated =[]
for i in range(len(category_array)):
    df1 =  df[df['Category']==category_array[i]]
    rate_count= df1['No of people Rated'].sum()
    no_of_rated.append(rate_count)

index =[ x for x in range(len(category_array))]

plt.bar(index,no_of_rated)
plt.xticks(index,category_array,rotation=90)
plt.xlabel("Category_of_Books")
plt.ylabel("No_of_rating")
plt.plot()
# Out:
# []

# %%
# getting the rating over the years 
import datetime as dt 

df['Date'] = pd.to_datetime(df['Date'])
df.Date.dtype
# Out:
# dtype('<M8[ns]')

# %%
def plot_rating_over_years():
    df['Date'].sort_values()
    df1 = df.groupby(df['Date'].dt.year)['Rating'].mean()
    df1 = pd.DataFrame(df1)
    y = df1.Rating.tolist() 
    x = df1.index 

    #plotting the average rating over the years 
    plt.plot(x,y)
    plt.xlabel('Years')
    plt.ylabel('Rating')
    plt.show()

plot_rating_over_years()

# %%
def plot_numpeople_rating():
    df1= df.groupby(df['Date'].dt.year)['No of people Rated'].count()
    # df1
    df1 = pd.DataFrame(df1)
    y = df1['No of people Rated'].tolist() 
    x = df1.index 

    #plotting the average rating over the years 
    plt.plot(x,y)
    plt.xlabel('Years')
    plt.ylabel('No of people Rated')
    plt.show()


plot_numpeople_rating()

# %%
from wordcloud import WordCloud

# %%
Category=df['Category'][~pd.isnull(df['Category'])]
wordCloud = WordCloud(width=350,height= 250).generate(' '.join(Category))
plt.figure(figsize=(19,9))
plt.axis('off')
plt.title(df['Category'].name,fontsize=20)
plt.imshow(wordCloud)
plt.show()
